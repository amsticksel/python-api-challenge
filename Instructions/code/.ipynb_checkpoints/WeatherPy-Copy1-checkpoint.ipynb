# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# Loop through the list of cities and perform a request for data on each
lat = []
lng = []
temp = []
cloud = []
country = []
date = []
humidity = []
maxtemp = []
wind = []
cityname = []

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        cityname.append(response['name'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        maxtemp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        print(f"finding {city}")
    except KeyError:
        print("Oops, that key doesn't exist.")
# Out:
# Oops, that key doesn't exist.
# finding bubaque
# finding cape town
# finding ushuaia
# finding sao mateus
# Oops, that key doesn't exist.
# finding tupik
# finding nicoya
# finding saskylakh
# Oops, that key doesn't exist.
# finding bredasdorp
# finding kyabram
# finding albany
# finding punta arenas
# finding lorengau
# finding mayor pablo lagerenza
# Oops, that key doesn't exist.
# finding port elizabeth
# finding hobart
# finding sai buri
# finding kodinsk
# finding mataura
# finding husavik
# Oops, that key doesn't exist.
# finding yonago
# finding jamestown
# finding chuy
# finding saint george
# finding bluff
# finding nome
# finding east london
# finding puerto madryn
# finding lompoc
# finding cabo rojo
# finding nanortalik
# finding laguna
# finding tuktoyaktuk
# finding hambantota
# finding hilo
# finding zamosc
# finding roald
# finding tiznit
# finding atuona
# finding kuusamo
# finding juneau
# finding namibe
# finding avera
# finding qingdao
# finding georgetown
# finding caravelas
# finding kaitangata
# finding hualmay
# finding udachnyy
# finding clyde river
# finding kieta
# finding carnarvon
# finding rozhnyativ
# Oops, that key doesn't exist.
# finding port-gentil
# finding houma
# finding pedernales
# finding ballina
# finding hermanus
# finding ribeira grande
# finding tigil
# finding rikitea
# finding pisco
# finding kapaa
# finding manokwari
# finding mayna
# finding jimenez
# finding diamantino
# finding qaanaaq
# finding bengkulu
# finding novosmolinskiy
# finding guerrero negro
# finding nushki
# finding codrington
# finding agadir
# finding gamboma
# finding busselton
# finding kodiak
# Oops, that key doesn't exist.
# finding xichang
# finding severobaykalsk
# finding galesong
# finding idenao
# finding khatanga
# finding sept-iles
# finding pachmarhi
# finding narsaq
# finding port hardy
# finding beringovskiy
# finding port alfred
# finding kismayo
# finding barrow
# Oops, that key doesn't exist.
# finding thompson
# finding kavaratti
# finding lebu
# finding iqaluit
# finding eucaliptus
# finding roma
# finding saldanha
# finding rabo de peixe
# finding mendoza
# finding yerbogachen
# finding upernavik
# finding magadan
# finding novobiryusinskiy
# finding new norfolk
# finding tabuk
# finding harlingen
# finding chokurdakh
# finding diapaga
# finding hithadhoo
# finding charters towers
# Oops, that key doesn't exist.
# finding hasaki
# Oops, that key doesn't exist.
# finding yellowknife
# finding nuevo san juan
# finding poum
# finding lazaro cardenas
# finding sulangan
# finding salalah
# finding isla vista
# Oops, that key doesn't exist.
# finding tiksi
# finding burns lake
# Oops, that key doesn't exist.
# finding klaksvik
# finding marzuq
# finding kahului
# finding puerto ayora
# Oops, that key doesn't exist.
# finding ancud
# finding buala
# finding aguimes
# finding tasiilaq
# finding shelabolikha
# finding vaini
# finding vao
# finding saint-philippe
# finding abancay
# finding vanavara
# finding kruisfontein
# Oops, that key doesn't exist.
# finding dikson
# Oops, that key doesn't exist.
# Oops, that key doesn't exist.
# finding ukiah
# finding muros
# finding perth
# finding norman wells
# finding pacific grove
# finding nyurba
# finding san quintin
# finding zalantun
# finding mana
# finding qandala
# finding shieli
# finding sao filipe
# finding nikolskoye
# finding fukue
# finding mayo
# finding maniitsoq
# finding saint-augustin
# finding yokadouma
# finding borehamwood
# finding campbellton
# finding bumba
# finding jacobina
# finding ruski krstur
# finding abha
# finding schwedt
# finding lishui
# finding coruripe
# finding nuevo progreso
# finding falkenberg
# finding chapais
# Oops, that key doesn't exist.
# finding ilulissat
# finding cherskiy
# finding baiyin
# finding bathsheba
# finding black river
# finding sao felix do xingu
# finding ibra
# finding takoradi
# finding ixtapa
# finding lagoa
# finding bethel
# finding coihaique
# finding nizhnevartovsk
# finding pasni
# finding cockburn town
# finding berlevag
# finding merauke
# finding severo-kurilsk
# finding asau
# finding kanye
# finding jos
# Oops, that key doesn't exist.
# Oops, that key doesn't exist.
# finding castro
# finding kotka
# Oops, that key doesn't exist.
# finding finnsnes
# finding vestmannaeyjar
# finding inirida
# finding samarai
# finding half moon bay
# finding marrakesh
# finding billings
# finding avarua
# finding syedove
# finding saint-georges
# finding vaitape
# finding bunia
# finding pattukkottai
# finding victoria
# finding mount gambier
# finding marataizes
# finding banjar
# finding dunedin
# finding ypsonas
# finding stornoway
# finding pangnirtung
# finding namatanai
# finding byumba
# finding hovd
# finding bambous virieux
# finding arraial do cabo
# finding lima
# Oops, that key doesn't exist.
# finding quatre cocos
# finding olafsvik
# finding butaritari
# Oops, that key doesn't exist.
# finding gunjur
# finding guayaramerin
# finding provideniya
# finding geraldton
# finding aksha
# finding waipawa
# finding luderitz
# Oops, that key doesn't exist.
# finding san cristobal
# finding fare
# finding constitucion
# finding la ronge
# finding riyadh
# finding iwanai
# finding abu kamal
# Oops, that key doesn't exist.
# finding hami
# finding axim
# finding matara
# finding dapaong
# finding pussi
# finding cabo san lucas
# finding monte alegre
# finding gravelbourg
# finding haines junction
# Oops, that key doesn't exist.
# finding airai
# finding ust-tsilma
# finding imbituba
# finding biak
# finding yei
# finding srivardhan
# finding garowe
# finding nakamura
# finding norsup
# finding nantucket
# finding garissa
# finding samfya
# finding port blair
# finding saint-pierre
# finding dodge city
# finding glazov
# finding antigonish
# finding progreso
# finding berea
# finding ahipara
# finding havoysund
# Oops, that key doesn't exist.
# finding port lincoln
# finding mar del plata
# finding cap malheureux
# finding westport
# finding tadine
# finding taoudenni
# finding raudeberg
# finding fortuna
# finding mahebourg
# finding tuatapere
# finding fairmont
# finding alofi
# finding manicore
# finding dickinson
# Oops, that key doesn't exist.
# finding san patricio
# finding kisanga
# finding kavieng
# Oops, that key doesn't exist.
# finding mehamn
# finding parkersburg
# finding eyrarbakki
# finding chokwe
# finding lavrentiya
# finding smithers
# Oops, that key doesn't exist.
# finding klyuchevskiy
# finding denpasar
# finding hobyo
# finding yinchuan
# finding puerto escondido
# finding yenagoa
# finding hounde
# finding coquimbo
# finding sozimskiy
# finding abu samrah
# Oops, that key doesn't exist.
# finding bhubaneswar
# finding jiazi
# finding tazovskiy
# finding tinambacan
# finding shellbrook
# Oops, that key doesn't exist.
# finding adelaide
# Oops, that key doesn't exist.
# finding vila
# finding monteagudo
# finding awbari
# finding mao
# finding englewood
# finding pevek
# finding calvinia
# finding tatawin
# finding sitka
# finding cayenne
# finding saint anthony
# finding kholtoson
# finding ogaminana
# finding antofagasta
# finding huilong
# finding vanimo
# finding saalfeld
# finding bandarbeyla
# finding katihar
# finding shimoda
# finding lasem
# finding katsuura
# finding kulunda
# finding sur
# finding atbasar
# finding saryg-sep
# Oops, that key doesn't exist.
# finding paamiut
# finding demba
# finding kovdor
# finding vila franca do campo
# finding gibara
# finding laurel
# finding rocha
# finding lakes entrance
# finding christchurch
# finding saint-joseph
# finding ostrovnoy
# finding mayahi
# finding burnie
# finding orange walk
# finding pemba
# finding faanui
# finding jacareacanga
# Oops, that key doesn't exist.
# Oops, that key doesn't exist.
# finding arlit
# finding makakilo city
# finding buchanan
# finding derbent
# finding tanout
# finding meulaboh
# Oops, that key doesn't exist.
# finding oktyabrskiy
# finding necochea
# finding batemans bay
# finding pudozh
# finding awjilah
# finding cabra
# Oops, that key doesn't exist.
# finding cabedelo
# finding takaka
# finding hays
# finding cap-aux-meules
# finding komsomolskiy
# finding sioux lookout
# finding portland
# finding baykit
# finding rawson
# finding ust-koksa
# finding shingu
# finding atar
# finding porto novo
# Oops, that key doesn't exist.
# finding paea
# finding otjimbingwe
# finding ojinaga
# finding ucluelet
# finding knysna
# finding souillac
# finding cabras
# finding formosa
# finding blythe
# finding ilebo
# finding palmer
# finding brae
# finding onega
# finding toora-khem
# finding yanam
# finding rio grande
# finding athabasca
# Oops, that key doesn't exist.
# finding port hedland
# finding hamilton
# finding barcelos
# finding lubango
# Oops, that key doesn't exist.
# finding balabac
# finding esperance
# finding auki
# finding balclutha
# finding aksarka
# finding cidreira
# finding alenquer
# Oops, that key doesn't exist.
# finding champerico
# finding wairoa
# finding aykhal
# finding praia da vitoria
# finding mrakovo
# finding qaqortoq
# finding hofn
# finding jagdalpur
# finding tomatlan
# finding waingapu
# finding oum hadjer
# finding usogorsk
# finding santa rita
# finding san lorenzo
# finding egvekinot
# Oops, that key doesn't exist.
# finding nosy varika
# finding leningradskiy
# finding kazanskoye
# finding bolgatanga
# finding san ramon
# finding port macquarie
# finding vardo
# Oops, that key doesn't exist.
# finding normandin
# finding nara
# finding marsh harbour
# finding sao jose da coroa grande
# finding amapa
# finding sao joao da barra
# finding hegang
# finding mokhsogollokh
# finding sumbawanga
# finding nhulunbuy
# finding deputatskiy
# finding jalu
# finding lata
# Oops, that key doesn't exist.
# finding huaraz
# finding okha
# finding san policarpo
# finding kupang
# finding kokopo
# finding el sauzal
# finding wewak
# finding palmeirais
# finding wahiawa
# finding miri
# finding san luis de la paz
# finding myre
# finding torbay
# finding arenapolis
# finding walvis bay
# finding mecca
# finding ingham
# finding ngunguru
# finding chiredzi
# finding college
# finding mikhaylovka
# finding tucupita
# finding arcata
# finding otjiwarongo
# finding mbeya
# finding korla
# finding divnomorskoye
# finding alamogordo
# finding nizwa
# finding emborion
# finding sola
# finding tongzi
# Oops, that key doesn't exist.
# finding havre-saint-pierre
# finding los llanos de aridane
# finding ratnagiri
# finding thinadhoo
# finding lasa
# Oops, that key doesn't exist.
# Oops, that key doesn't exist.
# finding iaciara
# finding rajshahi
# finding podolinec
# Oops, that key doesn't exist.
# finding mangai
# Oops, that key doesn't exist.
# Oops, that key doesn't exist.
# finding orlovskiy
# finding keti bandar
# finding eltham
# finding broome
# Oops, that key doesn't exist.
# finding bambanglipuro
# finding marawi
# finding kristiinankaupunki
# finding ubinskoye
# Oops, that key doesn't exist.
# Oops, that key doesn't exist.
# finding yumen
# finding nishihara
# finding arman
# finding gamba
# finding boende
# finding saint joseph
# finding myanaung
# finding makasar
# finding gold coast
# finding naryan-mar
# finding baiao
# finding kalabo
# finding severnoye
# finding vila velha
# finding bonnyville
# finding madang
# finding marystown
# finding manzanillo
# finding fremont
# finding ryotsu
# finding bangangte
# finding san ignacio
# finding schwerin
# finding durban
# finding labuhan
# finding ripky
# finding manggar
# finding bridlington
# Oops, that key doesn't exist.
# finding henties bay
# finding hoganas
# finding san pedro
# finding jinxiang
# finding pochutla
# finding suda
# finding yar-sale
# finding arroio grande
# finding naze
# finding majene
# finding andenes
# finding jibuti
# finding katobu
# finding sibolga
# finding sorong
# finding oranjestad
# finding bilma
# finding kondinskoye
# finding svetlyy
# finding twentynine palms
# finding muravlenko
# finding niquero
# finding puerto del rosario
# finding luganville
# finding otradnoye
# finding talant
# finding goderich
# finding srednekolymsk
# finding staryy nadym
# finding the valley
# finding gwanda
# finding itaituba
# finding luau
# finding honiara
# finding mantua
# finding tuy hoa
# finding clarksville
# finding patan
# finding mortka
# finding poronaysk
# finding taraclia
# finding koster
# finding strezhevoy

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = {'date': date,
                'city': cityname,
                'country': country,
                'lat': lat,
                'lng': lng,
                'temp': temp,
                'maxtemp': maxtemp,
                'humidity': humidity,
                'cloud': cloud,                
                'wind': wind,}

df = pd.DataFrame(weather_data, columns = ['date', 'city', 'country', 'lat', 'lng', 'temp', 'maxtemp', 'humidity', 'cloud', 'wind'])

# %%
df
# Out:
#            date        city country    lat     lng   temp  maxtemp  humidity  \
# 0    1578758306     Bubaque      GW  11.28  -15.83  26.55    26.55        53
# 1    1578758047   Cape Town      ZA -33.93   18.42  23.92    25.00        64
# 2    1578758126     Ushuaia      AR -54.80  -68.30  11.44    12.00        66
# 3    1578758306  Sao Mateus      BR -18.72  -39.86  31.32    31.32        49
# 4    1578758307       Tupik      RU  54.43  119.93 -23.83   -23.83        89
# ..          ...         ...     ...    ...     ...    ...      ...       ...
# 547  1578758348      Mortka      RU  59.33   66.02 -10.58   -10.58        94
# 548  1578758348   Poronaysk      RU  49.22  143.12  -7.81    -7.81        93
# 549  1578758348    Taraclia      MD  45.90   28.67   5.50     5.50        70
# 550  1578758348      Koster      ZA -25.86   26.90  24.20    24.20        57
# 551  1578758349  Strezhevoy      RU  60.73   77.59  -9.00    -9.00        78
#
#      cloud   wind
# 0       33   1.61
# 1        0   8.20
# 2       75  12.90
# 3       29   4.49
# 4       97   1.74
# ..     ...    ...
# 547    100   3.37
# 548    100   2.24
# 549     73   4.12
# 550     74   3.21
# 551    100   6.00
#
# [552 rows x 10 columns]

# %%
df.dtypes
# Out:
# date          int64
# city         object
# country      object
# lat         float64
# lng         float64
# temp        float64
# maxtemp     float64
# humidity      int64
# cloud         int64
# wind        float64
# dtype: object

# %%
df["date"] = pd.to_datetime(pd.Series(df["date"]), unit='s')
df["date"] = pd.to_datetime(pd.Series(df["date"]), format='%m%Y%d')
df['just_date'] = df['date'].dt.date

df.to_csv('weatherdata.csv')

dfweather = pd.read_csv('weatherdata.csv')
dfweather
# Out:
#      Unnamed: 0                 date        city country    lat     lng  \
# 0             0  2020-01-11 15:58:26     Bubaque      GW  11.28  -15.83
# 1             1  2020-01-11 15:54:07   Cape Town      ZA -33.93   18.42
# 2             2  2020-01-11 15:55:26     Ushuaia      AR -54.80  -68.30
# 3             3  2020-01-11 15:58:26  Sao Mateus      BR -18.72  -39.86
# 4             4  2020-01-11 15:58:27       Tupik      RU  54.43  119.93
# ..          ...                  ...         ...     ...    ...     ...
# 547         547  2020-01-11 15:59:08      Mortka      RU  59.33   66.02
# 548         548  2020-01-11 15:59:08   Poronaysk      RU  49.22  143.12
# 549         549  2020-01-11 15:59:08    Taraclia      MD  45.90   28.67
# 550         550  2020-01-11 15:59:08      Koster      ZA -25.86   26.90
# 551         551  2020-01-11 15:59:09  Strezhevoy      RU  60.73   77.59
#
#       temp  maxtemp  humidity  cloud   wind   just_date
# 0    26.55    26.55        53     33   1.61  2020-01-11
# 1    23.92    25.00        64      0   8.20  2020-01-11
# 2    11.44    12.00        66     75  12.90  2020-01-11
# 3    31.32    31.32        49     29   4.49  2020-01-11
# 4   -23.83   -23.83        89     97   1.74  2020-01-11
# ..     ...      ...       ...    ...    ...         ...
# 547 -10.58   -10.58        94    100   3.37  2020-01-11
# 548  -7.81    -7.81        93    100   2.24  2020-01-11
# 549   5.50     5.50        70     73   4.12  2020-01-11
# 550  24.20    24.20        57     74   3.21  2020-01-11
# 551  -9.00    -9.00        78    100   6.00  2020-01-11
#
# [552 rows x 12 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
dfweather.plot.scatter(x='lat', y='maxtemp', c='cadetblue', marker="o", s=11)
plt.title("Latitude vs. Temperature as of 1/10/2020")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (Celcius)")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
dfweather.plot.scatter(x='lat', y='humidity', c='cadetblue', marker="o", s=11)
plt.title("Latitude vs. Humidity as of 1/10/2020")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
dfweather.plot.scatter(x='lat', y='cloud', c='cadetblue', marker="o", s=11)
plt.title("Latitude vs. Cloudiness as of 1/10/2020")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
dfweather.plot.scatter(x='lat', y='wind', c='cadetblue', marker="o", s=11)
plt.title("Latitude vs. Wind Speed as of 1/10/2020")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

dfnorthern = dfweather[dfweather['lat'] >= 0]

dfsouthern = dfweather[dfweather['lat'] < 0]

# %%
dfnorthern
# Out:
#      Unnamed: 0                 date        city country    lat     lng  \
# 0             0  2020-01-11 15:58:26     Bubaque      GW  11.28  -15.83
# 4             4  2020-01-11 15:58:27       Tupik      RU  54.43  119.93
# 5             5  2020-01-11 15:58:27      Nicoya      CR  10.15  -85.45
# 6             6  2020-01-11 15:58:27   Saskylakh      RU  71.92  114.08
# 9             9  2020-01-11 15:55:09      Albany      US  42.60  -73.97
# ..          ...                  ...         ...     ...    ...     ...
# 546         546  2020-01-11 15:59:08       Patan      NP  27.67   85.33
# 547         547  2020-01-11 15:59:08      Mortka      RU  59.33   66.02
# 548         548  2020-01-11 15:59:08   Poronaysk      RU  49.22  143.12
# 549         549  2020-01-11 15:59:08    Taraclia      MD  45.90   28.67
# 551         551  2020-01-11 15:59:09  Strezhevoy      RU  60.73   77.59
#
#       temp  maxtemp  humidity  cloud  wind   just_date
# 0    26.55    26.55        53     33  1.61  2020-01-11
# 4   -23.83   -23.83        89     97  1.74  2020-01-11
# 5    25.67    31.00        52      0  9.30  2020-01-11
# 6   -19.26   -19.26        96    100  4.24  2020-01-11
# 9    13.20    15.56        67     75  6.20  2020-01-11
# ..     ...      ...       ...    ...   ...         ...
# 546   8.00     8.00        87     20  1.00  2020-01-11
# 547 -10.58   -10.58        94    100  3.37  2020-01-11
# 548  -7.81    -7.81        93    100  2.24  2020-01-11
# 549   5.50     5.50        70     73  4.12  2020-01-11
# 551  -9.00    -9.00        78    100  6.00  2020-01-11
#
# [369 rows x 12 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = dfnorthern['lat']
y_values = dfnorthern['maxtemp']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-40),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title("Northern Hemisphere Max Temperature -  Linear Regression")


# Print r square value
print(f"R squard: {rvalue}")

# Show plot
plt.show()
# Out:
# R squard: -0.8613186969754056

# %%
# Out:
# R squard: 0.5282688515036968

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = dfsouthern['lat']
y_values = dfsouthern['maxtemp']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,5),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title("Southern Hemisphere Max Temperature -  Linear Regression")


# Print r square value
print(f"R squard: {rvalue}")

# Show plot
plt.show()
# Out:
# R squard: 0.5282688515036968

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = dfnorthern['lat']
y_values = dfnorthern['humidity']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Northern Hemisphere Humidity -  Linear Regression")


# Print r square value
print(f"R squard: {rvalue}")

# Show plot
plt.show()
# Out:
# R squard: 0.42441536749248143

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = dfsouthern['lat']
y_values = dfsouthern['humidity']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Southern Hemisphere Humidity -  Linear Regression")


# Print r square value
print(f"R squard: {rvalue}")

# Show plot
plt.show()
# Out:
# R squard: 0.21533503516777072

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = dfnorthern['lat']
y_values = dfnorthern['cloud']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Northern Hemisphere Cloudiness -  Linear Regression")
# Print r square value
print(f"R squard: {rvalue}")

# Show plot
plt.show()
# Out:
# R squard: 0.25610850096800697

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = dfsouthern['lat']
y_values = dfsouthern['cloud']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Southern Hemisphere Cloudiness -  Linear Regression")
# Print r square value
print(f"R squard: {rvalue}")

# Show plot
plt.show()
# Out:
# R squard: 0.24226215150906327

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = dfnorthern['lat']
y_values = dfnorthern['wind']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,15),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Windspeed')
plt.title("Northern Hemisphere Wind Speed -  Linear Regression")
# Print r square value
print(f"R squard: {rvalue}")

# Show plot
plt.show()
# Out:
# R squard: 0.1519310942182751

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = dfsouthern['lat']
y_values = dfsouthern['wind']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Windspeed')
plt.title("Southern Hemisphere Wind Speed -  Linear Regression")
# Print r square value
print(f"R squard: {rvalue}")

# Show plot
plt.show()
# Out:
# R squard: -0.13277971619789913

# %% [markdown]
# ## Observations
# 1. Max temp increases as latitutde heads to 0. Both the northern and southern max temp charts show increase in temprature as you head to 0 latitude.
# 2. There is a very slight decrease in wind speed closer to the equator, but it is not a significant change. You can see that the slope is only -.04 for Southern Hemisphere with an R value of -.133, and a 0.02 slope with R value of .152 for Northern Hemisphere.
# 3. Humidity increases as latitutde increases. Both Northern and Southern hemisphere have a positive slope for this one.
